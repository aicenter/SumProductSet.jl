# %%
using DrWatson
@quickactivate 

using Flux, Graphs, Statistics, Plots, Zygote, GraphPlot
using Cairo, Compose
using SumProductSet
import Mill

# %% [markdown]
# # Graph clustering on simple toy graph

# %%
g = SimpleGraph(11)
for e in [(1, 2), (1, 3), (1, 4),
        (2, 4), (2, 5),
        (3, 4), (3, 5), (3, 6),
        (4, 5), (4, 6),

        (8, 9), (8, 7), (8, 10),
        (9, 7), (9, 6),
        (10, 7),
        (11, 8), (11, 9), (11, 10)
    ]
    add_edge!(g, e...)
end
vs = collect(vertices(g))
x = Flux.onehotbatch(vs, vs)
ds_train = Mill.BagNode(x, g.fadjlist)
# Out:
# BagNode 	# 11 obs, 896 bytes
#   └── ArrayNode(11×11 OneHotArray with Bool elements) 	# 11 obs, 100 bytes

# %%
m = reflectinmodel(ds_train[1], 2)
# Out:
# SumNode
#   ├── SetNode
#   │     ├── c: _Poisson
#   │     └── f: _Categorical
#   └── SetNode
#         ├── c: _Poisson
#         └── f: _Categorical

# %%
function train!(m, x; niter::Int=100, opt=ADAM(1.))
    ps = Flux.params(m)

    for i in 1:niter
        gs = gradient(() -> SumProductSet.ul_loss(m, x), ps)
        Flux.Optimise.update!(opt, ps, gs)
    end
end

predict = x->mapslices(argmax, logjnt(m, x), dims=1)[:]
# Out:
# #4 (generic function with 1 method)

# %%
train!(m, ds_train; opt=ADAM(0.02))
clusters = predict(ds_train)
colors = [colorant"yellow", colorant"red"]
nodelabel = 1:nv(g)
layout=_->spring_layout(g)
gplot(g, nodefillc=colors[clusters], layout=layout, nodelabel=nodelabel)
# Out:
# Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.7009577104022743cx, -0.9764407687523667cy), (-0.8873299533744606cx, -0.9932350151406285cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.6207595353092985cx, -0.8944723435422306cy), (-0.5949020153047258cx, -0.5150078999407081cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.6171564802681876cx, -0.8948049113562481cy), (-0.5975333237158251cx, -0.7264646501915961cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.9072772602830773cx, -0.948590814975286cy), (-0.6439320898346591cx, -0.703002962679563cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.9701148603728711cx, -0.925017637262473cy), (-0.9922887445823583cx, -0.7094042074061728cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.589431641548918cx, -0.5151815023113662cy), (-0.5891515954061078cx, -0.5762167349334262cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.6578799204171734cx, -0.472113551146996cy), (-0.9318975713753453cx, -0.6021127531115933cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.528241815773251cx, -0.39627080871306536cy), (-0.22245764125737322cx, -0.17994261735817668cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.6641179380133377cx, -0.6484486560645933cy), (-0.9246878071491694cx, -0.6375669662589014cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.5406455425415927cx, -0.5936074597399249cy), (-0.20908216785902cx, -0.1943952843962227cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.10742798094028494cx, -0.08330329987440341cy), (0.3578504825859523cx, 0.37859766502342884cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.8907097707024311cx, 0.6227831240580797cy), (0.8011067296737625cx, 0.7067091849186966cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.8727922478121279cx, 0.5522083597421408cy), (0.484276444659194cx, 0.4507491920620205cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.9551909018740452cx, 0.6460352352906761cy), (0.9905333237135039cx, 0.9252189848831612cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.6921342752639932cx, 0.7056039509348604cy), (0.46530246640842426cx, 0.4843374694984026cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.8006821269587953cx, 0.8102166057292544cy), (0.9454101478298491cx, 0.9480214830736846cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.6989199080286096cx, 0.8170308264163121cy), (0.6237587450539569cx, 0.9107070787859198cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.4334833890099783cx, 0.5037566890046199cy), (0.5544474561677166cx, 0.8974464590249971cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.9248169700668216cx, 0.9945842644188447cy), (0.6517694082271004cx, 0.9749155519804481cy)])], Symbol(""))]), List([Compose.Property{Compose.LineWidthPrimitive}(Compose.LineWidthPrimitive[Compose.LineWidthPrimitive(0.9045340337332909mm)]), Compose.Property{Compose.FillPrimitive}(Compose.FillPrimitive[Compose.FillPrimitive(RGBA{Float64}(0.0,0.0,0.0,0.0))]), Compose.Property{Compose.StrokePrimitive}(Compose.StrokePrimitive[Compose.StrokePrimitive(RGBA{Float64}(0.8274509803921568,0.8274509803921568,0.8274509803921568,1.0))])]), 0, false, false, false, fals ...
